# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("churn.csv")
df
# Out:
#      churn  accountlength internationalplan voicemailplan  \
# 0       No            128                no           yes
# 1       No            107                no           yes
# 2       No            137                no            no
# 3       No             84               yes            no
# 4       No             75               yes            no
# ...    ...            ...               ...           ...
# 4995    No             50                no           yes
# 4996   Yes            152                no            no
# 4997    No             61                no            no
# 4998    No            109                no            no
# 4999    No             86                no           yes
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 0                      25            265.1            110           45.07
# 1                      26            161.6            123           27.47
# ...

# %%
df.isnull().sum()
# Out:
# churn                         0
# accountlength                 0
# internationalplan             0
# voicemailplan                 0
# numbervmailmessages           0
# totaldayminutes               0
# totaldaycalls                 0
# totaldaycharge                0
# totaleveminutes               0
# totalevecalls                 0
# totalevecharge                0
# totalnightminutes             0
# totalnightcalls               0
# totalnightcharge              0
# totalintlminutes              0
# totalintlcalls                0
# totalintlcharge               0
# numbercustomerservicecalls    0
# dtype: int64

# %%
df.describe()
# Out:
#        accountlength  numbervmailmessages  totaldayminutes  totaldaycalls  \
# count     5000.00000          5000.000000      5000.000000    5000.000000
# mean       100.25860             7.755200       180.288900     100.029400
# std         39.69456            13.546393        53.894699      19.831197
# min          1.00000             0.000000         0.000000       0.000000
# 25%         73.00000             0.000000       143.700000      87.000000
# 50%        100.00000             0.000000       180.100000     100.000000
# 75%        127.00000            17.000000       216.200000     113.000000
# max        243.00000            52.000000       351.500000     165.000000
#
#        totaldaycharge  totaleveminutes  totalevecalls  totalevecharge  \
# count     5000.000000      5000.000000    5000.000000     5000.000000
# mean        30.649668       200.636560     100.191000       17.054322
# std          9.162069        50.551309      19.826496        4.296843
# ...

# %%
df.columns
# Out:
# Index(['churn', 'accountlength', 'internationalplan', 'voicemailplan',
#        'numbervmailmessages', 'totaldayminutes', 'totaldaycalls',
#        'totaldaycharge', 'totaleveminutes', 'totalevecalls', 'totalevecharge',
#        'totalnightminutes', 'totalnightcalls', 'totalnightcharge',
#        'totalintlminutes', 'totalintlcalls', 'totalintlcharge',
#        'numbercustomerservicecalls'],
#       dtype='object')

# %%
df
# Out:
#      churn  accountlength internationalplan voicemailplan  \
# 0       No            128                no           yes
# 1       No            107                no           yes
# 2       No            137                no            no
# 3       No             84               yes            no
# 4       No             75               yes            no
# ...    ...            ...               ...           ...
# 4995    No             50                no           yes
# 4996   Yes            152                no            no
# 4997    No             61                no            no
# 4998    No            109                no            no
# 4999    No             86                no           yes
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 0                      25            265.1            110           45.07
# 1                      26            161.6            123           27.47
# ...

# %%
df["internationalplan"]=df["internationalplan"].map({"no":0,"yes":1})
df["voicemailplan"]=df["voicemailplan"].map({"no":0,"yes":1})
df["churn"]=df["churn"].map({"No":0,"Yes":1})

# %%
df
# Out:
#       churn  accountlength  internationalplan  voicemailplan  \
# 0         0            128                  0              1
# 1         0            107                  0              1
# 2         0            137                  0              0
# 3         0             84                  1              0
# 4         0             75                  1              0
# ...     ...            ...                ...            ...
# 4995      0             50                  0              1
# 4996      1            152                  0              0
# 4997      0             61                  0              0
# 4998      0            109                  0              0
# 4999      0             86                  0              1
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 0                      25            265.1            110           45.07
# 1                      26            161.6            123           27.47
# ...

# %%
df1=df.drop(columns=['internationalplan','voicemailplan','churn'])
df1
# Out:
#       accountlength  numbervmailmessages  totaldayminutes  totaldaycalls  \
# 0               128                   25            265.1            110
# 1               107                   26            161.6            123
# 2               137                    0            243.4            114
# 3                84                    0            299.4             71
# 4                75                    0            166.7            113
# ...             ...                  ...              ...            ...
# 4995             50                   40            235.7            127
# 4996            152                    0            184.2             90
# 4997             61                    0            140.6             89
# 4998            109                    0            188.8             67
# 4999             86                   34            129.4            102
#
#       totaldaycharge  totaleveminutes  totalevecalls  totalevecharge  \
# ...

# %%
for column in df1:
    plt.figure()
    df1.boxplot([column],vert=False)

# %%
sns.boxplot(df["accountlength"])
# Out:
# <AxesSubplot:xlabel='accountlength'>

# %%
#this is our outliers

#Finding Outlier range
lower_bound=df.accountlength.mean()- 3*(df.accountlength.std())
Upper_bound=df.accountlength.mean()+ 3*(df.accountlength.std())

#Finding Outlier
df[(df["accountlength"]>Upper_bound) | (df["accountlength"]<lower_bound)]

df["accountlength"]=np.where(df.accountlength>Upper_bound,Upper_bound,np.where(df.accountlength<lower_bound,lower_bound,df.accountlength))

# %%
lower_bound=df.accountlength.mean()- 3*(df.accountlength.std())
Upper_bound=df.accountlength.mean()+ 3*(df.accountlength.std())

#Finding Outlier
df[(df["accountlength"]>Upper_bound) | (df["accountlength"]<lower_bound)]
# Out:
#       churn  accountlength  internationalplan  voicemailplan  \
# 416       1     219.342279                  1              0
# 817       0     219.342279                  0              0
# 1408      0     219.342279                  0              0
# 1551      1     219.342279                  0              0
# 1751      0     219.342279                  0              0
# 1886      0     219.342279                  0              0
# 3216      0     219.342279                  0              1
# 4260      0     219.342279                  0              0
# 4379      0     219.342279                  0              1
# 4389      0     219.342279                  0              0
# 4395      0     219.342279                  0              0
# 4798      1     219.342279                  0              0
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 416                     0            171.5             99           29.16
# ...

# %%
sns.boxplot(df.numbervmailmessages)
# Out:
# <AxesSubplot:xlabel='numbervmailmessages'>

# %%
lower_bound=df.numbervmailmessages.mean()- 3*(df.numbervmailmessages.std())
Upper_bound=df.numbervmailmessages.mean()+ 3*(df.numbervmailmessages.std())

#Finding Outlier
df[(df["numbervmailmessages"]>Upper_bound) | (df["numbervmailmessages"]<lower_bound)]

df["numbervmailmessages"]=np.where(df.numbervmailmessages>Upper_bound,Upper_bound,np.where(df.numbervmailmessages<lower_bound,lower_bound,df.numbervmailmessages))

# %%
lower_bound=df.numbervmailmessages.mean()- 3*(df.numbervmailmessages.std())
Upper_bound=df.numbervmailmessages.mean()+ 3*(df.numbervmailmessages.std())

#Finding Outlier
df[(df["numbervmailmessages"]>Upper_bound) | (df["numbervmailmessages"]<lower_bound)]
# Out:
#       churn  accountlength  internationalplan  voicemailplan  \
# 845       0          144.0                  0              1
# 1596      0           63.0                  0              1
# 2716      0          137.0                  0              1
# 2887      0          134.0                  0              1
# 3524      0           71.0                  0              1
# 3577      0          133.0                  0              1
# 4713      0          118.0                  1              1
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 845              48.39438            283.9             98           48.26
# 1596             48.39438            214.9             86           36.53
# 2716             48.39438            186.5             94           31.71
# 2887             48.39438            208.8            130           35.50
# 3524             48.39438            174.0            122           29.58
# ...

# %%
lower_bound=df.numbervmailmessages.mean()- 3*(df.numbervmailmessages.std())
upper_bound=df.numbervmailmessages.mean()+ 3*(df.numbervmailmessages.std())
df["numbervmailmessages"]=np.where(df.numbervmailmessages>upper_bound,df.numbervmailmessages.quantile(0.90),np.where(df.numbervmailmessages<lower_bound,df.numbervmailmessages.quantile(0.10),df.numbervmailmessages))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
print(df.numbervmailmessages.max())
print(df.numbervmailmessages.min())
# Out:
# 48.0
# 0.0

# %%
sns.boxplot(df.totaldayminutes)
# Out:
# <AxesSubplot:xlabel='totaldayminutes'>

# %%
print(df.totaldayminutes.max())
print(df.totaldayminutes.min())
# Out:
# 351.5
# 0.0

# %%
lower_bound=df.totaldayminutes.mean()- 3*(df.totaldayminutes.std())
upper_bound=df.totaldayminutes.mean()+ 3*(df.totaldayminutes.std())
df["totaldayminutes"]=np.where(df.totaldayminutes>upper_bound,df.totaldayminutes.quantile(0.90),np.where(df.totaldayminutes<lower_bound,df.totaldayminutes.quantile(0.10),df.totaldayminutes))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totaldayminutes)
# Out:
# <AxesSubplot:xlabel='totaldayminutes'>

# %%
print(df.totaldayminutes.max())
print(df.totaldayminutes.min())
# Out:
# 338.4
# 18.9

# %%
sns.boxplot(df.totaldaycalls)
# Out:
# <AxesSubplot:xlabel='totaldaycalls'>

# %%
df["totaldaycalls"]=np.where(df.totaldaycalls>upper_bound,df.totaldaycalls.quantile(0.90),np.where(df.totaldaycalls<lower_bound,df.totaldaycalls.quantile(0.10),df.totaldaycalls))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totaldaycalls)
# Out:
# <AxesSubplot:xlabel='totaldaycalls'>

# %%
sns.boxplot(df.totaldaycharge)
# Out:
# <AxesSubplot:xlabel='totaldaycharge'>

# %%
lower_bound=df.totaldaycharge.mean()- 3*(df.totaldaycharge.std())
upper_bound=df.totaldaycharge.mean()+ 3*(df.totaldaycharge.std())
df["totaldaycharge"]=np.where(df.totaldaycharge>upper_bound,df.totaldaycharge.quantile(0.90),np.where(df.totaldaycharge<lower_bound,df.totaldaycharge.quantile(0.10),df.totaldaycharge))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totaldaycharge)
# Out:
# <AxesSubplot:xlabel='totaldaycharge'>

# %%
sns.boxplot(df.totaleveminutes)
# Out:
# <AxesSubplot:xlabel='totaleveminutes'>

# %%
lower_bound=df.totaleveminutes.mean()- 3*(df.totaleveminutes.std())
upper_bound=df.totaleveminutes.mean()+ 3*(df.totaleveminutes.std())
df["totaleveminutes"]=np.where(df.totaleveminutes>upper_bound,df.totaleveminutes.quantile(0.90),np.where(df.totaleveminutes<lower_bound,df.totaleveminutes.quantile(0.10),df.totaleveminutes))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totaleveminutes)
# Out:
# <AxesSubplot:xlabel='totaleveminutes'>

# %%
sns.boxplot(df.totalevecalls)
# Out:
# <AxesSubplot:xlabel='totalevecalls'>

# %%
lower_bound=df.totalevecalls.mean()- 3*(df.totalevecalls.std())
upper_bound=df.totalevecalls.mean()+ 3*(df.totalevecalls.std())
df["totalevecalls"]=np.where(df.totalevecalls>upper_bound,df.totalevecalls.quantile(0.90),np.where(df.totalevecalls<lower_bound,df.totalevecalls.quantile(0.10),df.totalevecalls))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalevecharge)
# Out:
# <AxesSubplot:xlabel='totalevecharge'>

# %%
lower_bound=df.totalevecharge.mean()- 3*(df.totalevecharge.std())
upper_bound=df.totalevecharge.mean()+ 3*(df.totalevecharge.std())
df["totalevecharge"]=np.where(df.totalevecharge>upper_bound,df.totalevecharge.quantile(0.90),np.where(df.totalevecharge<lower_bound,df.totalevecharge.quantile(0.10),df.totalevecharge))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalnightminutes)
# Out:
# <AxesSubplot:xlabel='totalnightminutes'>

# %%
lower_bound=df.totalnightminutes.mean()- 3*(df.totalnightminutes.std())
upper_bound=df.totalnightminutes.mean()+ 3*(df.totalnightminutes.std())
df["totalnightminutes"]=np.where(df.totalnightminutes>upper_bound,df.totalnightminutes.quantile(0.90),np.where(df.totalnightminutes<lower_bound,df.totalnightminutes.quantile(0.10),df.totalnightminutes))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalnightcalls)
# Out:
# <AxesSubplot:xlabel='totalnightcalls'>

# %%
lower_bound=df.totalnightcalls.mean()- 3*(df.totalnightcalls.std())
upper_bound=df.totalnightcalls.mean()+ 3*(df.totalnightcalls.std())
df["totalnightcalls"]=np.where(df.totalnightcalls>upper_bound,df.totalnightcalls.quantile(0.90),np.where(df.totalnightcalls<lower_bound,df.totalnightcalls.quantile(0.10),df.totalnightcalls))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalnightcharge)
# Out:
# <AxesSubplot:xlabel='totalnightcharge'>

# %%
lower_bound=df.totalnightcharge.mean()- 3*(df.totalnightcharge.std())
upper_bound=df.totalnightcharge.mean()+ 3*(df.totalnightcharge.std())
df["totalnightcharge"]=np.where(df.totalnightcharge>upper_bound,df.totalnightcharge.quantile(0.90),np.where(df.totalnightcharge<lower_bound,df.totalnightcharge.quantile(0.10),df.totalnightcharge))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalintlminutes)
# Out:
# <AxesSubplot:xlabel='totalintlminutes'>

# %%
lower_bound=df.totalintlminutes.mean()- 3*(df.totalintlminutes.std())
upper_bound=df.totalintlminutes.mean()+ 3*(df.totalintlminutes.std())
df["totalintlminutes"]=np.where(df.totalintlminutes>upper_bound,df.totalintlminutes.quantile(0.90),np.where(df.totalintlminutes<lower_bound,df.totalintlminutes.quantile(0.10),df.totalintlminutes))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.	totalintlcalls)
# Out:
# <AxesSubplot:xlabel='totalintlcalls'>

# %%
lower_bound=df.totalintlcalls.mean()- 3*(df.totalintlcalls.std())
upper_bound=df.totalintlcalls.mean()+ 3*(df.totalintlcalls.std())
df["totalintlcalls"]=np.where(df.totalintlcalls>upper_bound,df.totalintlcalls.quantile(0.90),np.where(df.totalintlcalls<lower_bound,df.totalintlcalls.quantile(0.10),df.totalintlcalls))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.totalintlcharge)
# Out:
# <AxesSubplot:xlabel='totalintlcharge'>

# %%
lower_bound=df.totalintlcharge.mean()- 3*(df.totalintlcharge.std())
upper_bound=df.totalintlcharge.mean()+ 3*(df.totalintlcharge.std())
df["totalintlcharge"]=np.where(df.totalintlcharge>upper_bound,df.totalintlcharge.quantile(0.90),np.where(df.totalintlcharge<lower_bound,df.totalintlcharge.quantile(0.10),df.totalintlcharge))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
sns.boxplot(df.numbercustomerservicecalls)
# Out:
# <AxesSubplot:xlabel='numbercustomerservicecalls'>

# %%
lower_bound=df.numbercustomerservicecalls.mean()- 3*(df.numbercustomerservicecalls.std())
upper_bound=df.numbercustomerservicecalls.mean()+ 3*(df.numbercustomerservicecalls.std())
df["numbercustomerservicecalls"]=np.where(df.numbercustomerservicecalls>upper_bound,df.numbercustomerservicecalls.quantile(0.90),np.where(df.numbercustomerservicecalls<lower_bound,df.numbercustomerservicecalls.quantile(0.10),df.numbercustomerservicecalls))
print("Outlier Capped")
# Out:
# Outlier Capped

# %%
df
# Out:
#       churn  accountlength  internationalplan  voicemailplan  \
# 0         0          128.0                  0              1
# 1         0          107.0                  0              1
# 2         0          137.0                  0              0
# 3         0           84.0                  1              0
# 4         0           75.0                  1              0
# ...     ...            ...                ...            ...
# 4995      0           50.0                  0              1
# 4996      1          152.0                  0              0
# 4997      0           61.0                  0              0
# 4998      0          109.0                  0              0
# 4999      0           86.0                  0              1
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 0                    25.0            265.1          110.0           45.07
# 1                    26.0            161.6          123.0           27.47
# ...

# %%
df.internationalplan.value_counts()
# Out:
# 0    4527
# 1     473
# Name: internationalplan, dtype: int64

# %%
df.voicemailplan.value_counts()
# Out:
# 0    3677
# 1    1323
# Name: voicemailplan, dtype: int64

# %%
df.churn.value_counts()#imabalance dataset
# Out:
# 0    4293
# 1     707
# Name: churn, dtype: int64

# %%
X=df.drop(columns=['churn'])
X
# Out:
#       accountlength  internationalplan  voicemailplan  numbervmailmessages  \
# 0             128.0                  0              1                 25.0
# 1             107.0                  0              1                 26.0
# 2             137.0                  0              0                  0.0
# 3              84.0                  1              0                  0.0
# 4              75.0                  1              0                  0.0
# ...             ...                ...            ...                  ...
# 4995           50.0                  0              1                 40.0
# 4996          152.0                  0              0                  0.0
# 4997           61.0                  0              0                  0.0
# 4998          109.0                  0              0                  0.0
# 4999           86.0                  0              1                 34.0
#
# ...

# %%
X.describe()
# Out:
#        accountlength  internationalplan  voicemailplan  numbervmailmessages  \
# count    5000.000000        5000.000000    5000.000000          5000.000000
# mean      100.236821           0.094600       0.264600             7.730000
# std        39.625266           0.292691       0.441164            13.484312
# min         1.000000           0.000000       0.000000             0.000000
# 25%        73.000000           0.000000       0.000000             0.000000
# 50%       100.000000           0.000000       0.000000             0.000000
# 75%       127.000000           0.000000       1.000000            17.000000
# max       219.342279           1.000000       1.000000            48.000000
#
#        totaldayminutes  totaldaycalls  totaldaycharge  totaleveminutes  \
# count      5000.000000    5000.000000     5000.000000      5000.000000
# mean        180.398030     100.059400       30.668217       200.780896
# ...

# %%
Y=df['churn']
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4995    0
# 4996    1
# 4997    0
# 4998    0
# 4999    0
# Name: churn, Length: 5000, dtype: int64

# %%
df["churned"]=(df["churn"])
df
# Out:
#       churn  accountlength  internationalplan  voicemailplan  \
# 0         0          128.0                  0              1
# 1         0          107.0                  0              1
# 2         0          137.0                  0              0
# 3         0           84.0                  1              0
# 4         0           75.0                  1              0
# ...     ...            ...                ...            ...
# 4995      0           50.0                  0              1
# 4996      1          152.0                  0              0
# 4997      0           61.0                  0              0
# 4998      0          109.0                  0              0
# 4999      0           86.0                  0              1
#
#       numbervmailmessages  totaldayminutes  totaldaycalls  totaldaycharge  \
# 0                    25.0            265.1          110.0           45.07
# 1                    26.0            161.6          123.0           27.47
# ...

# %%
df.drop(['churn'],axis=1,inplace=True)
df
# Out:
#       accountlength  internationalplan  voicemailplan  numbervmailmessages  \
# 0             128.0                  0              1                 25.0
# 1             107.0                  0              1                 26.0
# 2             137.0                  0              0                  0.0
# 3              84.0                  1              0                  0.0
# 4              75.0                  1              0                  0.0
# ...             ...                ...            ...                  ...
# 4995           50.0                  0              1                 40.0
# 4996          152.0                  0              0                  0.0
# 4997           61.0                  0              0                  0.0
# 4998          109.0                  0              0                  0.0
# 4999           86.0                  0              1                 34.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=.25,random_state=45,stratify=df.churned) #we have imbalance data hence stratifying

 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn import metrics


scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(xtrain)
x_test_scaled= scaler.transform(xtest)
LG=LogisticRegression().fit(x_train_scaled,ytrain)
ypred=LG.predict(x_test_scaled)
print("ACCuracy=",accuracy_score(ytest,ypred))

#result=LG.predict(scaler.transform([[]]))

#result[0]

print(metrics.classification_report(ytest,ypred))
# Out:
# ACCuracy= 0.8672
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      1073
#            1       0.60      0.19      0.29       177
#
#     accuracy                           0.87      1250
#    macro avg       0.74      0.59      0.61      1250
# weighted avg       0.84      0.87      0.84      1250

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=.25,random_state=7,stratify=df.churned)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn import metrics


scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(xtrain)
x_test_scaled= scaler.transform(xtest)
knn=KNeighborsClassifier(n_neighbors=5).fit(x_train_scaled,ytrain)
ypred=knn.predict(x_test_scaled)
print("ACCuracy=",accuracy_score(ytest,ypred))

#result=LG.predict(scaler.transform([[]]))

#result[0]

print(metrics.classification_report(ytest,ypred))
# Out:
# ACCuracy= 0.9048
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      1073
#            1       0.86      0.39      0.54       177
#
#     accuracy                           0.90      1250
#    macro avg       0.89      0.69      0.74      1250
# weighted avg       0.90      0.90      0.89      1250

# %%
import pickle
pickle.dump(knn,open("model.pkl","wb"))

# %%
pickle.dump(scaler,open("scaler.pkl","wb"))

# %%
rs=knn.predict(scaler.transform([[128,0,1,25,265,110,45,197,99,17,247,91,11,10,3,2,1]]))
rs[0]
